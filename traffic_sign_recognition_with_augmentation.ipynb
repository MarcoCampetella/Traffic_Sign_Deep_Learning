# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from imgaug import augmenters as iaa
from sklearn.preprocessing import StandardScaler
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
data = []
labels = []
classes = 43
img_size = (26,26)
cur_path = os.getcwd()
#print(cur_path)

# %%
seq = iaa.Sequential([
    iaa.Crop(px=(0, 10)), # crop images from each side by 0 to 16px (randomly chosen)
    iaa.Fliplr(0.5), # horizontally flip 50% of the images
    iaa.GaussianBlur(sigma=(0, 3.0)) # blur images with a sigma of 0 to 3.0
]) # apply augmenters in random order
#images_aug = seq(images=images)

# %%
#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'archive/Train',str(i))
    images = os.listdir(path)

    for a in images:
        try:
            #print(path + '/'+ a)
            image = Image.open(path + '/'+ a)
            image = image.resize(img_size)
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

# %%
#Converting lists into numpy arrays
data02 = np.array(data)
labels02 = np.array(labels)

# %%
print(data02.shape, labels02.shape)
# Out:
# (39209, 26, 26, 3) (39209,)

# %%
unique,counts = np.unique(labels02,return_counts=True)
dizionario = dict(zip(unique,counts))
massimo = np.max(counts)
#massimo = np.max(counts)
#massimo = max(dizionario, key=dizionario.get)
#minimo = min(dizionario, key=dizionario.get)
print((massimo))
#print((minimo))
#print(dizionario)
# Out:
# 2250

# %%
#i=2
#print(len(data02[labels02==i,:,:,:]))
#data_app = data02[labels02==i,:,:,:]
#print(data_app.shape)

# %%
#2250//2250

# %%
#print(type(data02[labels02==0,:,:,:][0]))
#print(data02[labels02==0,:,:,:][0].shape)
#print(data02[labels02==0,:,:,:][1].shape)

# %%
data_augmented=[]
labels_aug = []
count = 0
for i in range(classes):
    n_augments = massimo//counts[i]
    for l in range(counts[i]):
        data_augmented.append(data02[labels02==i,:,:,:][l])
        labels_aug.append(i)
        count += 1
    print("n augments = %5d for class %5d" %(n_augments-1,i) )    
    for j in range(n_augments-1):
#        print(i,j)
        data_aug = seq(images=data02[labels02==i,:,:,:])
#        print(data_aug.shape)   
        for k in range(counts[i]):
            data_augmented.append(data_aug[i,:,:,:])
            labels_aug.append(i)
            count += 1

data_augmented = np.array(data_augmented)
labels_aug = np.array(labels_aug)
print(data_augmented.shape)
print(labels_aug.shape)
#print(type(data_augmented))
#print(data_augmented[0].shape)
# Out:
# n augments =     9 for class     0
# n augments =     0 for class     1
# n augments =     0 for class     2
# n augments =     0 for class     3
# n augments =     0 for class     4
# n augments =     0 for class     5
# n augments =     4 for class     6
# n augments =     0 for class     7
# n augments =     0 for class     8
# n augments =     0 for class     9
# n augments =     0 for class    10
# n augments =     0 for class    11
# n augments =     0 for class    12
# n augments =     0 for class    13
# n augments =     1 for class    14
# n augments =     2 for class    15
# n augments =     4 for class    16
# n augments =     1 for class    17
# n augments =     0 for class    18
# n augments =     9 for class    19
# n augments =     5 for class    20
# n augments =     5 for class    21
# n augments =     4 for class    22
# n augments =     3 for class    23
# n augments =     7 for class    24
# n augments =     0 for class    25
# n augments =     2 for class    26
# n augments =     8 for class    27
# n augments =     3 for class    28
# n augments =     7 for class    29
# n augments =     4 for class    30
# n augments =     1 for class    31
# n augments =     8 for class    32
# n augments =     2 for class    33
# n augments =     4 for class    34
# n augments =     0 for class    35
# n augments =     4 for class    36
# n augments =     9 for class    37
# n augments =     0 for class    38
# n augments =     6 for class    39
# n augments =     5 for class    40
# n augments =     8 for class    41
# n augments =     8 for class    42
# (83007, 26, 26, 3)
# (83007,)

# %%
print(data_augmented.min(), data_augmented.max(), data_augmented.std())
# calculate global mean and standard deviation
mean, std = data_augmented.mean(), data_augmented.std()
print('Mean: %.3f, Standard Deviation: %.3f' % (mean, std))
# Out:
# 0 255 62.29674740558667
# Mean: 83.664, Standard Deviation: 62.297

# %%
# global standardization of pixels
data_augmented = (data_augmented - mean) / std
# clip pixel values to [-1,1]
data_augmented = np.clip(data_augmented, -1.0, 1.0)
# shift from [-1,1] to [0,1] with 0.5 mean
data_augmented = (data_augmented + 1.0) / 2.0
# confirm it had the desired effect
mean, std = data_augmented.mean(), data_augmented.std()
print('Mean: %.3f, Standard Deviation: %.3f' % (mean, std))
print('Min: %.3f, Max: %.3f' % (data_augmented.min(), data_augmented.max()))
# Out:
# Mean: 0.434, Standard Deviation: 0.357
# Min: 0.000, Max: 1.000

# %%
#print(counts[24])
print("the starting dataset has dimensions : ",data02.shape)
print("the post processing dataset has dimensions : ", data_augmented.shape)
# Out:
# the starting dataset has dimensions :  (39209, 26, 26, 3)
# the post processing dataset has dimensions :  (83007, 26, 26, 3)

# %%
print(np.all((data_augmented[labels_aug==2,:,:,:] == data02[labels02==2,:,:,:])))
# Out:
# False

# %%
unique_aug,counts_aug = np.unique(labels_aug,return_counts=True)

# %%
fig = plt.figure(num=1,figsize = (10, 5))
plt.bar(unique_aug, counts_aug, color ='blue',
        width = 0.4)
 
plt.xlabel("Classes")
plt.ylabel("Occurrence")
plt.title("Class Distribution after Preprocessing")
fig.savefig('dist_after_proc.png', dpi=300) 
plt.show()

# %%
#print(data.shape, labels.shape)
#Splitting training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(data_augmented, labels_aug, test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#Converting the labels into one hot encoding
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)
# Out:
# (66405, 26, 26, 3) (16602, 26, 26, 3) (66405,) (16602,)

# %%
#Building the model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(4,4), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(4,4), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))
# Out:
# Metal device set to: Apple M1 Max
# 2022-01-17 17:01:08.847080: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-01-17 17:01:08.848088: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

epochs = 50
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
model.save("my_model_aug_std.h5")
# Out:
# 2022-01-17 17:01:28.384166: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-01-17 17:01:28.387293: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 2022-01-17 17:01:35.166604: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2076/2076 [==============================] - ETA: 0s - loss: 1.7008 - accuracy: 0.5358
# 2022-01-17 17:01:58.535321: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2076/2076 [==============================] - 33s 13ms/step - loss: 1.7004 - accuracy: 0.5360 - val_loss: 0.1420 - val_accuracy: 0.9595
# Epoch 2/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.1995 - accuracy: 0.9410 - val_loss: 0.0806 - val_accuracy: 0.9747
# Epoch 3/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.1307 - accuracy: 0.9605 - val_loss: 0.0715 - val_accuracy: 0.9771
# Epoch 4/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.1012 - accuracy: 0.9694 - val_loss: 0.0677 - val_accuracy: 0.9806
# Epoch 5/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0904 - accuracy: 0.9720 - val_loss: 0.0499 - val_accuracy: 0.9855
# Epoch 6/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0850 - accuracy: 0.9736 - val_loss: 0.0498 - val_accuracy: 0.9852
# Epoch 7/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0704 - accuracy: 0.9777 - val_loss: 0.0497 - val_accuracy: 0.9852
# Epoch 8/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0800 - accuracy: 0.9751 - val_loss: 0.0386 - val_accuracy: 0.9878
# Epoch 9/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0690 - accuracy: 0.9790 - val_loss: 0.0490 - val_accuracy: 0.9839
# Epoch 10/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0603 - accuracy: 0.9810 - val_loss: 0.0392 - val_accuracy: 0.9878
# Epoch 11/50
# 2076/2076 [==============================] - 368s 177ms/step - loss: 0.0663 - accuracy: 0.9799 - val_loss: 0.0383 - val_accuracy: 0.9881
# Epoch 12/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0611 - accuracy: 0.9822 - val_loss: 0.0404 - val_accuracy: 0.9877
# Epoch 13/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0605 - accuracy: 0.9825 - val_loss: 0.0340 - val_accuracy: 0.9904
# Epoch 14/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0574 - accuracy: 0.9833 - val_loss: 0.0442 - val_accuracy: 0.9861
# Epoch 15/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0646 - accuracy: 0.9811 - val_loss: 0.0346 - val_accuracy: 0.9905
# Epoch 16/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0608 - accuracy: 0.9820 - val_loss: 0.0373 - val_accuracy: 0.9901
# Epoch 17/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0600 - accuracy: 0.9829 - val_loss: 0.0338 - val_accuracy: 0.9910
# Epoch 18/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0548 - accuracy: 0.9848 - val_loss: 0.0375 - val_accuracy: 0.9895
# Epoch 19/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0510 - accuracy: 0.9857 - val_loss: 0.0366 - val_accuracy: 0.9914
# Epoch 20/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0653 - accuracy: 0.9834 - val_loss: 0.0331 - val_accuracy: 0.9920
# Epoch 21/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0526 - accuracy: 0.9853 - val_loss: 0.0400 - val_accuracy: 0.9895
# Epoch 22/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0625 - accuracy: 0.9834 - val_loss: 0.0406 - val_accuracy: 0.9900
# Epoch 23/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0544 - accuracy: 0.9845 - val_loss: 0.0540 - val_accuracy: 0.9855
# Epoch 24/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0632 - accuracy: 0.9831 - val_loss: 0.0363 - val_accuracy: 0.9904
# Epoch 25/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0506 - accuracy: 0.9862 - val_loss: 0.0362 - val_accuracy: 0.9908
# Epoch 26/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0543 - accuracy: 0.9859 - val_loss: 0.0453 - val_accuracy: 0.9898
# Epoch 27/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0627 - accuracy: 0.9845 - val_loss: 0.0446 - val_accuracy: 0.9883
# Epoch 28/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0436 - accuracy: 0.9871 - val_loss: 0.0391 - val_accuracy: 0.9904
# Epoch 29/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0659 - accuracy: 0.9846 - val_loss: 0.0356 - val_accuracy: 0.9907
# Epoch 30/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0605 - accuracy: 0.9846 - val_loss: 0.0372 - val_accuracy: 0.9908
# Epoch 31/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0642 - accuracy: 0.9846 - val_loss: 0.0381 - val_accuracy: 0.9914
# Epoch 32/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0615 - accuracy: 0.9849 - val_loss: 0.0441 - val_accuracy: 0.9902
# Epoch 33/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0581 - accuracy: 0.9858 - val_loss: 0.0373 - val_accuracy: 0.9907
# Epoch 34/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0571 - accuracy: 0.9859 - val_loss: 0.0468 - val_accuracy: 0.9898
# Epoch 35/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0581 - accuracy: 0.9856 - val_loss: 0.0482 - val_accuracy: 0.9899
# Epoch 36/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0621 - accuracy: 0.9866 - val_loss: 0.0529 - val_accuracy: 0.9888
# Epoch 37/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0560 - accuracy: 0.9865 - val_loss: 0.0460 - val_accuracy: 0.9900
# Epoch 38/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0720 - accuracy: 0.9837 - val_loss: 0.0573 - val_accuracy: 0.9870
# Epoch 39/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0677 - accuracy: 0.9845 - val_loss: 0.0401 - val_accuracy: 0.9920
# Epoch 40/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0650 - accuracy: 0.9865 - val_loss: 0.0464 - val_accuracy: 0.9895
# Epoch 41/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0560 - accuracy: 0.9866 - val_loss: 0.0432 - val_accuracy: 0.9912
# Epoch 42/50
# 2076/2076 [==============================] - 26s 12ms/step - loss: 0.0705 - accuracy: 0.9859 - val_loss: 0.0468 - val_accuracy: 0.9907
# Epoch 43/50
# 2076/2076 [==============================] - 465s 224ms/step - loss: 0.0721 - accuracy: 0.9852 - val_loss: 0.0397 - val_accuracy: 0.9904
# Epoch 44/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0769 - accuracy: 0.9850 - val_loss: 0.0512 - val_accuracy: 0.9905
# Epoch 45/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0682 - accuracy: 0.9856 - val_loss: 0.0429 - val_accuracy: 0.9907
# Epoch 46/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0676 - accuracy: 0.9860 - val_loss: 0.0348 - val_accuracy: 0.9921
# Epoch 47/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0676 - accuracy: 0.9862 - val_loss: 0.0613 - val_accuracy: 0.9874
# Epoch 48/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0764 - accuracy: 0.9855 - val_loss: 0.0443 - val_accuracy: 0.9918
# Epoch 49/50
# 2076/2076 [==============================] - 27s 13ms/step - loss: 0.0905 - accuracy: 0.9843 - val_loss: 0.0422 - val_accuracy: 0.9917
# Epoch 50/50
# 2076/2076 [==============================] - 26s 13ms/step - loss: 0.0638 - accuracy: 0.9864 - val_loss: 0.0500 - val_accuracy: 0.9904

# %%
#plotting graphs for accuracy 
fig = plt.figure(num=0,figsize = (10, 5))
plt.figure(0)
plt.plot(history.history['accuracy'][0:20], label='training accuracy')
plt.plot(history.history['val_accuracy'][0:20], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
fig.savefig('accuracy_aug.png', dpi=300)
plt.show()

fig = plt.figure(num=1,figsize = (10, 5))
plt.figure(1)
plt.plot(history.history['loss'][0:20], label='training loss')
plt.plot(history.history['val_loss'][0:20], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
fig.savefig('loss_aug.png', dpi=300)
plt.show()

# %%
#testing accuracy on test dataset
from sklearn.metrics import accuracy_score

y_test = pd.read_csv('Test.csv')

#y_test["Path"] = y_test["Path"].str.cat("archive", sep="/")
#print(y_test["Path"][0:10])

labels = y_test["ClassId"].values

path_img = "./archive/"

imgs = path_img + y_test["Path"].values


data=[]

for img in imgs:
    image = Image.open(img)
    image = image.resize(img_size)
    data.append(np.array(image))

X_test=np.array(data)

print(X_test.shape)

pred = model.predict_classes(X_test)

#Accuracy with the test data
from sklearn.metrics import accuracy_score
print(accuracy_score(labels, pred))
# Out:
# (12630, 26, 26, 3)
# /Users/gatsu82/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 2022-01-17 17:43:12.053216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 0.9503562945368171
